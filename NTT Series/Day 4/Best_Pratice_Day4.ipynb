# %% [markdown]
# # requirements.txt
# numpy==1.26.4
# pandas==2.1.4
# scikit-learn==1.3.2
# fastapi==0.115.5
# uvicorn==0.30.0

# %%
#It covers: KPI-driven problem framing, baseline benchmarking, cost-sensitive thresholding, cross-validation, bootstrap confidence intervals, model persistence, and a FastAPI serving endpoint.
